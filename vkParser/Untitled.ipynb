# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("posts.csv", encoding = 'UTF-8', delimiter=',')

# %%
del data['id']
data
# Out:
#            date  views  likes  reposts  \
# 0    1601040600    419      1        0
# 1    1601015401    543      2        1
# 2    1600954202    565      1        0
# 3    1600929001    563      1        0
# 4    1600842601    697      8        0
# ..          ...    ...    ...      ...
# 995  1502442925    331      2        0
# 996  1502180218    382      2        1
# 997  1502087242    301      1        0
# 998  1501753143    455      3        2
# 999  1501500691    314      7        0
#
#                                                   body  comments
# 0    СПЕЦИАЛИСТ ПО ОБСЛУЖИВАНИЮ СРЕДСТВ ПЕЧАТИ В БА...         0
# 1    Вакансия Frontend-разработчика \n\nПАО «МегаФо...         0
# 2    В связи с расширением компании требуется PHP Р...         0
# 3    Приглашаем 17-18 октября в Белгород на Хакатон...         0
# 4    Начинающая игровая студия \nиз г. Самара ищет ...         0
# ..                                                 ...       ...
# ...
